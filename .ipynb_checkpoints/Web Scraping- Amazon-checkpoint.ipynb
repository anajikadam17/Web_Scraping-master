# %% [markdown]
# # Web Scraping- Amazon Best Sellers

# %% [markdown]
# #### Crawling through each Department in best sellers and scraping information
#
# The same can be used for amazon "gift ideas", "new releases" tabs

# %%
#importing required libraries

import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import numpy as np

# %%
url = "https://www.amazon.in/gp/bestsellers/"

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
content = BeautifulSoup(response.text, 'html')

# %%
type(content)
# Out:
# bs4.BeautifulSoup

# %%
best_seller = content.find(id="zg_left_col2")

# %%
best_seller_dict= {}
for i in best_seller.find_all("a"):
    best_seller_dict[i.text] = i["href"]
best_seller_dict
# Out:
# {'Amazon Launchpad': 'https://www.amazon.in/gp/bestsellers/boost',
#  'Apps for Android': 'https://www.amazon.in/gp/bestsellers/mobile-apps',
#  'Baby Products': 'https://www.amazon.in/gp/bestsellers/baby',
#  'Bags, Wallets and Luggage': 'https://www.amazon.in/gp/bestsellers/luggage',
#  'Beauty': 'https://www.amazon.in/gp/bestsellers/beauty',
#  'Books': 'https://www.amazon.in/gp/bestsellers/books',
#  'Car & Motorbike': 'https://www.amazon.in/gp/bestsellers/automotive',
#  'Clothing & Accessories': 'https://www.amazon.in/gp/bestsellers/apparel',
#  'Computers & Accessories': 'https://www.amazon.in/gp/bestsellers/computers',
#  'Electronics': 'https://www.amazon.in/gp/bestsellers/electronics',
#  'Garden & Outdoors': 'https://www.amazon.in/gp/bestsellers/garden',
#  'Gift Cards': 'https://www.amazon.in/gp/bestsellers/gift-cards',
#  'Grocery & Gourmet Foods': 'https://www.amazon.in/gp/bestsellers/grocery',
#  'Health & Personal Care': 'https://www.amazon.in/gp/bestsellers/hpc',
#  'Home & Kitchen': 'https://www.amazon.in/gp/bestsellers/kitchen',
#  'Home Improvement': 'https://www.amazon.in/gp/bestsellers/home-improvement',
#  'Industrial & Scientific': 'https://www.amazon.in/gp/bestsellers/industrial',
#  'Jewellery': 'https://www.amazon.in/gp/bestsellers/jewelry',
#  'Kindle Store': 'https://www.amazon.in/gp/bestsellers/digital-text',
#  'Movies & TV Shows': 'https://www.amazon.in/gp/bestsellers/dvd',
#  'Music': 'https://www.amazon.in/gp/bestsellers/music',
#  'Musical Instruments': 'https://www.amazon.in/gp/bestsellers/musical-instruments',
#  'Office Products': 'https://www.amazon.in/gp/bestsellers/office',
#  'Pet Supplies': 'https://www.amazon.in/gp/bestsellers/pet-supplies',
#  'Shoes & Handbags': 'https://www.amazon.in/gp/bestsellers/shoes',
#  'Software': 'https://www.amazon.in/gp/bestsellers/software',
#  'Sports, Fitness & Outdoors': 'https://www.amazon.in/gp/bestsellers/sports',
#  'Toys & Games': 'https://www.amazon.in/gp/bestsellers/toys',
#  'Video Games': 'https://www.amazon.in/gp/bestsellers/videogames',
#  'Watches': 'https://www.amazon.in/gp/bestsellers/watches'}

# %%
rank = []
product_link = []
Name = []
Rating = []
review_link = []
total_reviews = []
Price = []
Dep = []
page = []


for k,v in best_seller_dict.items():
    print(k)
    for j in range(1,3):
        if v != "0":
            time.sleep(2)
            url = requests.get(v)
            resp_text = BeautifulSoup(url.text, 'html')
            bst_sellr = resp_text.find(id="zg-right-col")
            for i in bst_sellr.find(id="zg-center-div").find(id="zg-ordered-list").find_all(class_="zg-item-immersion"):
                try:
                    page.append(j)
                except AttributeError:
                    page.append(np.nan)
                    
                try:
                    Dep.append(k)
                except AttributeError:
                    Dep.append(np.nan)
                    
                try:
                    rank.append(i.find(class_="zg-badge-text").text)
                except AttributeError:
                    rank.append(np.nan)
                    
                try:
                    product_link.append("https://www.amazon.in" + i.find("span",{"class":"aok-inline-block zg-item"}).find("a",{"class":"a-link-normal"})["href"])
                except AttributeError:
                    product_link.append(np.nan)
                    
                try:
                    Name.append(i.find("span",{"class":"aok-inline-block zg-item"}).find("a",{"class":"a-link-normal"}).text.strip())
                except AttributeError:
                    Name.append(np.nan)
                    
                try:
                    Rating.append(i.find("span",{"class":"aok-inline-block zg-item"}).find("div",{"class":"a-icon-row a-spacing-none"}).find("a",{"class":"a-link-normal"})['title'])
                except AttributeError:
                    Rating.append(np.nan)
                    
                try:
                    review_link.append("https://www.amazon.in" + i.find("span",{"class":"aok-inline-block zg-item"}).find("div",{"class":"a-icon-row a-spacing-none"}).find("a",{"class":"a-link-normal"})['href'])
                except AttributeError:
                    review_link.append(np.nan)
                    
                try:
                    total_reviews.append(i.find("span",{"class":"aok-inline-block zg-item"}).find("div",{"class":"a-icon-row a-spacing-none"}).find("a",{"class":"a-size-small a-link-normal"}).text)
                except AttributeError:
                    total_reviews.append(np.nan)
                    
                try:
                    Price.append(i.find("span",{"class":"aok-inline-block zg-item"}).find("a",{"class":"a-link-normal a-text-normal"}).find("span",{"class":"a-size-base a-color-price"}).find("span",{"class":"p13n-sc-price"}).text)
                except AttributeError:
                    Price.append(np.nan)
            try:
                v = bst_sellr.find(id="zg-center-div").find("div",{"class":"a-row a-spacing-top-mini"}).find("ul",{"class":"a-pagination"}).find("li",{"class":"a-normal"}).find("a")["href"]
            except:
                v = "0"
# Out:
# Amazon Launchpad
# Apps for Android
# Baby Products
# Bags, Wallets and Luggage
# Beauty
# Books
# Car & Motorbike
# Clothing & Accessories
# Computers & Accessories
# Electronics
# Garden & Outdoors
# Gift Cards
# Grocery & Gourmet Foods
# Health & Personal Care
# Home & Kitchen
# Home Improvement
# Industrial & Scientific
# Jewellery
# Kindle Store
# Movies & TV Shows
# Music
# Musical Instruments
# Office Products
# Pet Supplies
# Shoes & Handbags
# Software
# Sports, Fitness & Outdoors
# Toys & Games
# Video Games
# Watches

# %%
Amazon_best = pd.DataFrame({"Department":Dep,"Page":page,"Rank":rank,'Name':Name,"Product_link":product_link,"Rating":Rating,"Review_link":review_link,"Total_reviews":total_reviews, "Price":Price})

# %%
Amazon_best
# Out:
#             Department  Page  Rank  \
# 0     Amazon Launchpad     1    #1
# 1     Amazon Launchpad     1    #2
# 2     Amazon Launchpad     1    #3
# 3     Amazon Launchpad     1    #4
# 4     Amazon Launchpad     1    #5
# 5     Amazon Launchpad     1    #6
# 6     Amazon Launchpad     1    #7
# 7     Amazon Launchpad     1    #8
# 8     Amazon Launchpad     1    #9
# 9     Amazon Launchpad     1   #10
# 10    Amazon Launchpad     1   #11
# 11    Amazon Launchpad     1   #12
# 12    Amazon Launchpad     1   #13
# 13    Amazon Launchpad     1   #14
# 14    Amazon Launchpad     1   #15
# 15    Amazon Launchpad     1   #16
# 16    Amazon Launchpad     1   #17
# 17    Amazon Launchpad     1   #18
# 18    Amazon Launchpad     1   #19
# 19    Amazon Launchpad     1   #20
# 20    Amazon Launchpad     1   #21
# 21    Amazon Launchpad     1   #22
# 22    Amazon Launchpad     1   #23
# 23    Amazon Launchpad     1   #24
# 24    Amazon Launchpad     1   #25
# 25    Amazon Launchpad     1   #26
# 26    Amazon Launchpad     1   #27
# 27    Amazon Launchpad     1   #28
# 28    Amazon Launchpad     1   #29
# 29    Amazon Launchpad     1   #30
# ...                ...   ...   ...
# 2956           Watches     2   #71
# 2957           Watches     2   #72
# 2958           Watches     2   #73
# 2959           Watches     2   #74
# 2960           Watches     2   #75
# 2961           Watches     2   #76
# 2962           Watches     2   #77
# 2963           Watches     2   #78
# 2964           Watches     2   #79
# 2965           Watches     2   #80
# 2966           Watches     2   #81
# 2967           Watches     2   #82
# 2968           Watches     2   #83
# 2969           Watches     2   #84
# 2970           Watches     2   #85
# 2971           Watches     2   #86
# 2972           Watches     2   #87
# 2973           Watches     2   #88
# 2974           Watches     2   #89
# 2975           Watches     2   #90
# 2976           Watches     2   #91
# 2977           Watches     2   #92
# 2978           Watches     2   #93
# 2979           Watches     2   #94
# 2980           Watches     2   #95
# 2981           Watches     2   #96
# 2982           Watches     2   #97
# 2983           Watches     2   #98
# 2984           Watches     2   #99
# 2985           Watches     2  #100
#
#                                                    Name  \
# 0     Bodyguard Reusable Anti Pollution Face Mask wi...
# 1     Avant Men's Ultra Light Running and Training S...
# 2     OZiva Protein & Herbs, Women, Whey Protein wit...
# 3     Neuherbs Organic Green Coffee Beans Powder for...
# 4     YaYa cafe Valentine Greeting Card for Girlfrie...
# 5     Dr Vaidya's Herbobuild - Ayurvedic Capsules fo...
# 6     Control D Blue & White Compressor Complete Kit...
# 7                        Auravedic Kumkumadi Oil, 100ml
# 8      Neuherbs Green Coffee Beans for Weight Loss 400g
# 9     Mansaa Essentials - Copper String LED Lights -...
# 10           PEESAFE Toilet Seat Sanitizer Spray - 75ml
# 11    Nurturing Green Chamaedorea Palm Plant in Herm...
# 12               Nurturing Green Lucky Bamboo Two Layer
# 13    Intellilens® Square Unisex Blue Cut Spectacles...
# 14    Yogabar Breakfast Protein Variety (Almond Coco...
# 15    Yogabars Multigrain Energy Bars Variety Box - ...
# 16    Crack of Dawn Crafts 3 Layered All Occasion Ex...
# 17    Sirona Reusable Menstrual Cup with no Rashes, ...
# 18                          HORNBULL Brown Men's Wallet
# 3                ₹ 339.00
# 4     ₹ 149.00 - ₹ 399.00
# 5                ₹ 328.00
# 6                ₹ 949.00
# 7                ₹ 289.00
# 8                ₹ 309.00
# 9     ₹ 299.00 - ₹ 349.00
# 10               ₹ 180.00
# 11    ₹ 159.00 - ₹ 250.00
# 12    ₹ 250.00 - ₹ 549.00
# 13               ₹ 749.00
# 14               ₹ 241.00
# 15               ₹ 332.00
# 16               ₹ 331.00
# 17               ₹ 349.00
# 18               ₹ 549.00
# 19               ₹ 949.00
# 20               ₹ 276.00
# 21               ₹ 279.00
# 22               ₹ 220.00
# 23               ₹ 599.00
# 24               ₹ 356.00
# 25             ₹ 1,999.00
# 26    ₹ 499.00 - ₹ 599.00
# 27                    NaN
# 28               ₹ 239.00
# 29               ₹ 155.00
# ...                   ...
# 2956           ₹ 1,695.00
# 2957             ₹ 715.00
# 2958             ₹ 399.00
# 2959           ₹ 1,915.00
# 2960             ₹ 212.00
# 2961           ₹ 1,915.00
# 2962  ₹ 249.00 - ₹ 299.00
# 2963  ₹ 590.00 - ₹ 599.00
# 2964           ₹ 1,165.00
# 2965           ₹ 1,160.00
# 2966           ₹ 2,067.00
# 2967              ₹ 99.00
# 2968           ₹ 2,075.00
# 2969                  NaN
# 2970             ₹ 649.00
# 2971             ₹ 720.00
# 2972             ₹ 265.00
# 2973             ₹ 349.00
# 2974           ₹ 1,975.00
# 2975             ₹ 249.00
# 2976             ₹ 795.00
# 2977             ₹ 235.00
# 2978           ₹ 1,515.00
# 2979             ₹ 575.00
# 2980             ₹ 299.00
# 2981             ₹ 575.00
# 2982             ₹ 238.00
# 2983             ₹ 575.00
# 2984           ₹ 4,995.00
# 2985           ₹ 1,695.00
#
# [2986 rows x 9 columns]

# %%
Amazon_best.isnull().sum()
# Out:
# Department        0
# Page              0
# Rank              0
# Name              1
# Product_link      1
# Rating           79
# Review_link      79
# Total_reviews    79
# Price            98
# dtype: int64

# %%
Amazon_best.loc[Amazon_best.Department == 'Jewellery']
# Out:
#      Department  Page  Rank  \
# 1636  Jewellery     1    #1
# 1637  Jewellery     1    #2
# 1638  Jewellery     1    #3
# 1639  Jewellery     1    #4
# 1640  Jewellery     1    #5
# ...         ...   ...   ...
# 1731  Jewellery     2   #96
# 1732  Jewellery     2   #97
# 1733  Jewellery     2   #98
# 1734  Jewellery     2   #99
# 1735  Jewellery     2  #100
#
#                                                    Name  \
# 1636                     Sukkhi Jewellery Set for Women
# 1637  Shining Diva Fashion Jewellery Fancy Party Wea...
# 1638  Sukkhi Gold Plated Jewellery Set for Women (CB...
# 1639  Youbella Antique German Silver Oxidised Plated...
# 1640                  Yellow Chimes Metal Ring for Mens
# ...                                                 ...
# 1731  Jianhua 10 Grid Compact Small Size Jewellery B...
# 1732  YouBella Jewellery Sets for Women Silver Plate...
# 1733  Yellow Chimes Platinum Plated Elegant Classic ...
# 1734  Karatcart GoldPlated Fashion Chandbali Hook Da...
# 1735  I Jewels Traditional Kundan & Pearl Choker Nec...
#
#                                            Product_link              Rating  \
# 1636  https://www.amazon.in/Sukkhi-Jewellery-Set-for...  3.8 out of 5 stars
# 1637  https://www.amazon.in/Shining-Diva-Fashion-Jew...  4.3 out of 5 stars
# 1638  https://www.amazon.in/Sukkhi-Sparkling-Plated-...  3.6 out of 5 stars
# 1639  https://www.amazon.in/Youbella-Antique-Oxidise...  4.2 out of 5 stars
# 1640  https://www.amazon.in/Yellow-Chimes-Metal-Ring...  4.0 out of 5 stars
# ...                                                 ...                 ...
# 1731  https://www.amazon.in/Jianhua-Grid-Compact-Jew...  3.2 out of 5 stars
# 1732  https://www.amazon.in/YouBella-Jewellery-Afgha...  2.7 out of 5 stars
# 1733  https://www.amazon.in/Yellow-Chimes-Platinum-E...  3.9 out of 5 stars
# 1734  https://www.amazon.in/Karatcart-GoldPlated-Fas...  4.1 out of 5 stars
# 1735  https://www.amazon.in/Jewels-Traditional-Kunda...  4.4 out of 5 stars
#
#                                            Review_link Total_reviews  \
# 1636  https://www.amazon.in/product-reviews/B07H6JVQM4         1,085
# 1637  https://www.amazon.in/product-reviews/B0753DHRBR           848
# 1638  https://www.amazon.in/product-reviews/B07BCGHN9H           301
# 1639  https://www.amazon.in/product-reviews/B07F8T9465           470
# 1640  https://www.amazon.in/product-reviews/B07DGT5CPF           432
# ...                                                ...           ...
# 1731  https://www.amazon.in/product-reviews/B07DYXQDWL            78
# 1732  https://www.amazon.in/product-reviews/B07T5DXT3R             6
# 1733  https://www.amazon.in/product-reviews/B07QYT22JN            57
# 1734  https://www.amazon.in/product-reviews/B07RCYYF2P            53
# 1735  https://www.amazon.in/product-reviews/B079S7FNYV           305
#
#                     Price
# 1636  ₹ 199.00 - ₹ 550.00
# 1637             ₹ 185.00
# 1638             ₹ 189.00
# 1639  ₹ 275.00 - ₹ 335.00
# 1640  ₹ 199.00 - ₹ 333.00
# ...                   ...
# 1731             ₹ 299.00
# 1732  ₹ 499.00 - ₹ 549.00
# 1733  ₹ 199.00 - ₹ 275.00
# 1734             ₹ 299.00
# 1735             ₹ 535.00
#
# [100 rows x 9 columns]

# %%
# for getting pages 

pages_dict = {}
for j in bst_sellr.find(id="zg-center-div").find("div",{"class":"a-row a-spacing-top-mini"}):
    pages_dict[j.find("ul",{"class":"a-pagination"}).find("li",{"class":"a-selected"}).find("a").text] = j.find("ul",{"class":"a-pagination"}).find("li",{"class":"a-selected"}).find("a")["href"]
    pages_dict[j.find("ul",{"class":"a-pagination"}).find("li",{"class":"a-normal"}).find("a").text]=j.find("ul",{"class":"a-pagination"}).find("li",{"class":"a-normal"}).find("a")["href"]
pages_dict
# Out:
# {'2': 'https://www.amazon.in/gp/bestsellers/watches?ie=UTF8&pg=2',
#  '1': 'https://www.amazon.in/gp/bestsellers/watches?ie=UTF8&pg=1'}

# %%
Amazon_best.to_excel('Amazon_Best.xlsx',index = False)
